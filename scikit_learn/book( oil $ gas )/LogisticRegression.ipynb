# %% [markdown]
# # logisticRegression
# ### <span style="color:red"> used in binary calssification

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# ### the data used is to predict whether the employee will quit or not
# - 0 > will not
# - 1 > will quit

# %%
df=pd.read_excel("D:/Programming/DATA - SCIENCE/oil_data/Chapter 5/Logistic Regression (LR)/Chapter5_HR_DataSet.xlsx")

# %%
df
# Out:
#      Late show up percentage  Project initiative percentage  \
# 0                   0.477912                       0.517593
# 1                   0.298068                       0.403864
# 2                   0.353470                       0.545904
# 3                   0.684900                       0.678940
# 4                   0.714167                       0.365101
# ..                       ...                            ...
# 995                 0.540622                       0.425615
# 996                 0.259226                       0.369436
# 997                 0.621092                       0.388595
# 998                 0.588408                       0.301913
# 999                 0.428501                       0.373313
#
#      Percentage of project delivery on time  Percentage of emails exchanged  \
# 0                                  0.255846                        0.446856
# 1                                  0.234836                        0.490999
# ...

# %% [markdown]
# ### from the first see , we know that we don't need to scale the input as it already scaled [0,1] as it is percentage

# %% [markdown]
# ## [ 1 ] show the distribution of each input

# %%
f,axes=plt.subplots(nrows=5,ncols=2,figsize=(15,15))
f.suptitle("the distribution of each input")
sns.distplot(df["Late show up percentage"],color='red',ax=axes[0,0])
sns.distplot(df[df.columns[1]],color='#333',ax=axes[0,1])
sns.distplot(df[df.columns[2]],color='#bbb',ax=axes[1,0])
sns.distplot(df[df.columns[3]],color='yellow',ax=axes[1,1])
sns.distplot(df[df.columns[4]],color='blue',ax=axes[2,0])
sns.distplot(df[df.columns[5]],color='green',ax=axes[2,1])
sns.distplot(df[df.columns[6]],color='#bbbb',ax=axes[3,0])
sns.distplot(df[df.columns[7]],color='black',ax=axes[3,1])
sns.distplot(df[df.columns[8]],color='red',ax=axes[4,0])
sns.distplot(df[df.columns[9]],color='blue',ax=axes[4,1])
plt.tight_layout()
# Out:
# c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
f,axes=plt.subplots(nrows=5,ncols=2,figsize=(15,15))
f.suptitle("the distribution of each input")
sns.violinplot(df["Late show up percentage"],color='red',ax=axes[0,0])
sns.violinplot(df[df.columns[1]],color='#333',ax=axes[0,1])
sns.violinplot(df[df.columns[2]],color='#bbb',ax=axes[1,0])
sns.violinplot(df[df.columns[3]],color='yellow',ax=axes[1,1])
sns.violinplot(df[df.columns[4]],color='blue',ax=axes[2,0])
sns.violinplot(df[df.columns[5]],color='green',ax=axes[2,1])
sns.violinplot(df[df.columns[6]],color='#bbbb',ax=axes[3,0])
sns.violinplot(df[df.columns[7]],color='black',ax=axes[3,1])
sns.violinplot(df[df.columns[8]],color='red',ax=axes[4,0])
sns.violinplot(df[df.columns[9]],color='blue',ax=axes[4,1])
plt.tight_layout()
# Out:
# c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ## from the grapghs , <span style="color:red"> there is almost no outliers

# %% [markdown]
# ## [2] let's see the collerations between the features

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap="viridis",linewidth=1,linecolor="#fff")
plt.show()

# %% [markdown]
# ## Degree of correlation:
#
# - <span style="color:red">Perfect</span>: If the value is near ± 1, then it said to be a perfect correlation: as one variable increases, the other variable tends to also increase (if positive) or decrease (if negative).
# - <span style="color:red">High degree </span>: If the coefficient value lies between ± 0.50 and ± 1, then it is said to be a strong correlation.
# - <span style="color:red">Moderate degree </span>: If the value lies between ± 0.30 and ± 0.49, then it is said to be a medium correlation.
# - <span style="color:red">Low degree </span>: When the value lies below + .29, then it is said to be a small correlation.
# - <span style="color:red">No correlation </span>: When the value is zero.

# %% [markdown]
# ### so form the heatmap:
# - there is no collinear features
# - we will take all the features

# %%
X = df.drop("Quitting",axis=1)
Y=df["Quitting"]
Y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 995    1
# 996    0
# 997    1
# 998    1
# 999    1
# Name: Quitting, Length: 1000, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
lr=LogisticRegression(penalty='l2',C=1,solver='lbfgs')
# which is the defult parameters

# %%
x_train,x_test,y_train,Y_test=train_test_split(X,Y,test_size=.3)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1)

# %%
y_pred=lr.predict(x_test)

# %% [markdown]
# ## model evaluation

# %%
plt.figure()
sns.heatmap(confusion_matrix(Y_test,y_pred),annot=True,cmap="viridis")
# the horizontal is the predicted
# the virtical is the actual
# Out:
# <AxesSubplot:>

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95       155
#            1       0.93      0.97      0.95       145
#
#     accuracy                           0.95       300
#    macro avg       0.95      0.95      0.95       300
# weighted avg       0.95      0.95      0.95       300

# %% [markdown]
# ## apply the girdsearch

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={"penalty":['l1', 'l2', 'elasticnet', 'none'],
         "C":np.linspace(.01,10,20),
        "solver":['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
       }
log=LogisticRegression()
log_cv=GridSearchCV(log,params,cv=5)

# %%
log_cv.fit(x_train,y_train)
# Out:
# c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# ...

# %%
log_cv.best_params_
# Out:
# {'C': 1.0615789473684212, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
log_cv.best_score_
# Out:
# 0.9471428571428572

# %%
y_pred2=log_cv.predict(x_test)

# %%
print(classification_report(y_pred2,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       150
#            1       0.97      0.93      0.95       150
#
#     accuracy                           0.95       300
#    macro avg       0.95      0.95      0.95       300
# weighted avg       0.95      0.95      0.95       300
